# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32')).to(DEVICE)
  y_train = torch.tensor(data['y'].transpose().astype('long')).type(torch.LongTensor).to(DEVICE) #added due to error
  x_test= torch.tensor(data['x_test'].astype('float32')).to(DEVICE)
  y_test = torch.tensor(data['y_test'].astype('long')).type(torch.LongTensor).to(DEVICE)

  model.to(DEVICE)

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302428, train error 89.57,  test loss 2.302762, test error 90.30
# Epoch   100, train loss 2.302207, train error 89.57,  test loss 2.303494, test error 90.30
# Epoch   200, train loss 2.302210, train error 89.57,  test loss 2.303369, test error 90.30
# Epoch   300, train loss 2.302210, train error 89.57,  test loss 2.303474, test error 90.30
# Epoch   400, train loss 2.302209, train error 89.57,  test loss 2.303424, test error 90.30
# Epoch   500, train loss 2.302214, train error 89.57,  test loss 2.303358, test error 90.30
# Epoch   600, train loss 2.302211, train error 89.57,  test loss 2.303411, test error 90.30
# Epoch   700, train loss 2.302213, train error 89.57,  test loss 2.303418, test error 90.30
# Epoch   800, train loss 2.302215, train error 89.57,  test loss 2.303526, test error 90.30
# Epoch   900, train loss 2.302211, train error 89.57,  test loss 2.303417, test error 90.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301058, train error 90.30,  test loss 2.302223, test error 89.93
# Epoch   100, train loss 1.810517, train error 66.27,  test loss 1.662408, test error 63.25
# Epoch   200, train loss 1.759063, train error 63.12,  test loss 1.591103, test error 59.88
# Epoch   300, train loss 1.753453, train error 62.70,  test loss 1.593768, test error 60.70
# Epoch   400, train loss 1.753088, train error 62.80,  test loss 1.590046, test error 60.72
# Epoch   500, train loss 1.751561, train error 62.80,  test loss 1.588622, test error 60.65
# Epoch   600, train loss 1.750438, train error 63.00,  test loss 1.587184, test error 60.32
# Epoch   700, train loss 1.749507, train error 62.75,  test loss 1.588432, test error 60.67
# Epoch   800, train loss 1.751242, train error 62.97,  test loss 1.589767, test error 60.88
# Epoch   900, train loss 1.750803, train error 62.38,  test loss 1.604721, test error 60.67
# Training model with   6 hidden variables
# Epoch     0, train loss 2.258576, train error 85.12,  test loss 2.250971, test error 84.50
# Epoch   100, train loss 1.720527, train error 61.90,  test loss 1.587443, test error 61.15
# Epoch   200, train loss 1.688161, train error 60.65,  test loss 1.593536, test error 61.22
# Epoch   300, train loss 1.674473, train error 59.75,  test loss 1.579422, test error 61.97
# Epoch   400, train loss 1.638553, train error 57.20,  test loss 1.557047, test error 59.05
# Epoch   500, train loss 1.612244, train error 56.30,  test loss 1.508286, test error 57.50
# Epoch   600, train loss 1.599758, train error 55.92,  test loss 1.484365, test error 56.75
# Epoch   700, train loss 1.596048, train error 55.92,  test loss 1.483226, test error 56.37
# Epoch   800, train loss 1.599753, train error 56.07,  test loss 1.492900, test error 56.85
# Epoch   900, train loss 1.587118, train error 55.85,  test loss 1.474656, test error 56.57
# Training model with   8 hidden variables
# Epoch     0, train loss 2.272185, train error 84.97,  test loss 2.265079, test error 84.88
# Epoch   100, train loss 1.599613, train error 55.32,  test loss 1.441871, test error 52.55
# Epoch   200, train loss 1.542048, train error 53.02,  test loss 1.385667, test error 51.32
# Epoch   300, train loss 1.525573, train error 52.67,  test loss 1.384527, test error 51.67
# Epoch   400, train loss 1.519742, train error 52.47,  test loss 1.399220, test error 52.55
# Epoch   500, train loss 1.508150, train error 51.70,  test loss 1.401612, test error 52.17
# Epoch   600, train loss 1.503144, train error 51.47,  test loss 1.400557, test error 52.22
# Epoch   700, train loss 1.504490, train error 51.92,  test loss 1.400035, test error 52.22
# Epoch   800, train loss 1.503825, train error 51.52,  test loss 1.412950, test error 52.52
# Epoch   900, train loss 1.501419, train error 51.85,  test loss 1.404065, test error 51.42
# Training model with  10 hidden variables
# Epoch     0, train loss 2.303539, train error 88.97,  test loss 2.299653, test error 88.85
# Epoch   100, train loss 1.599018, train error 54.25,  test loss 1.489865, test error 57.05
# Epoch   200, train loss 1.515509, train error 51.72,  test loss 1.409123, test error 52.12
# Epoch   300, train loss 1.500583, train error 50.52,  test loss 1.395473, test error 50.97
# Epoch   400, train loss 1.489465, train error 50.47,  test loss 1.398352, test error 51.57
# Epoch   500, train loss 1.489434, train error 50.72,  test loss 1.407100, test error 51.17
# Epoch   600, train loss 1.488828, train error 51.35,  test loss 1.413012, test error 51.27
# Epoch   700, train loss 1.481206, train error 51.12,  test loss 1.394002, test error 51.12
# Epoch   800, train loss 1.482436, train error 50.80,  test loss 1.403963, test error 51.15
# Epoch   900, train loss 1.475191, train error 50.60,  test loss 1.414818, test error 51.07
# Training model with  14 hidden variables
# Epoch     0, train loss 2.282324, train error 84.93,  test loss 2.272361, test error 83.45
# Epoch   100, train loss 1.531158, train error 52.30,  test loss 1.473066, test error 56.30
# Epoch   200, train loss 1.356083, train error 44.35,  test loss 1.326831, test error 48.40
# Epoch   300, train loss 1.327369, train error 43.62,  test loss 1.346715, test error 49.47
# Epoch   400, train loss 1.301519, train error 43.17,  test loss 1.328543, test error 48.27
# Epoch   500, train loss 1.281600, train error 42.27,  test loss 1.341742, test error 48.72
# Epoch   600, train loss 1.278047, train error 42.12,  test loss 1.348951, test error 48.12
# Epoch   700, train loss 1.275817, train error 41.60,  test loss 1.364583, test error 48.95
# Epoch   800, train loss 1.269785, train error 41.80,  test loss 1.370775, test error 48.65
# Epoch   900, train loss 1.263724, train error 41.60,  test loss 1.382596, test error 48.92
# Training model with  18 hidden variables
# Epoch     0, train loss 2.159707, train error 81.30,  test loss 2.106550, test error 79.93
# Epoch   100, train loss 1.348244, train error 44.65,  test loss 1.290830, test error 47.95
# Epoch   200, train loss 1.258056, train error 41.65,  test loss 1.328868, test error 49.32
# Epoch   300, train loss 1.215941, train error 40.52,  test loss 1.368378, test error 49.15
# Epoch   400, train loss 1.201411, train error 40.40,  test loss 1.391212, test error 49.02
# Epoch   500, train loss 1.174123, train error 39.32,  test loss 1.427231, test error 50.27
# Epoch   600, train loss 1.158798, train error 38.67,  test loss 1.453201, test error 50.90
# Epoch   700, train loss 1.155526, train error 39.30,  test loss 1.480765, test error 50.67
# Epoch   800, train loss 1.149373, train error 39.20,  test loss 1.520569, test error 51.65
# Epoch   900, train loss 1.131347, train error 38.15,  test loss 1.507576, test error 50.50
# Training model with  22 hidden variables
# Epoch     0, train loss 2.192563, train error 80.80,  test loss 2.157186, test error 80.65
# Epoch   100, train loss 1.296018, train error 42.80,  test loss 1.336031, test error 49.45
# Epoch   200, train loss 1.174110, train error 39.72,  test loss 1.381397, test error 49.52
# Epoch   300, train loss 1.121140, train error 38.35,  test loss 1.433221, test error 50.20
# Epoch   400, train loss 1.090953, train error 37.27,  test loss 1.465806, test error 50.50
# Epoch   500, train loss 1.076664, train error 36.80,  test loss 1.531259, test error 52.20
# Epoch   600, train loss 1.052870, train error 35.80,  test loss 1.570552, test error 52.67
# Epoch   700, train loss 1.040540, train error 35.38,  test loss 1.568357, test error 52.00
# Epoch   800, train loss 1.036016, train error 35.55,  test loss 1.604399, test error 52.87
# Epoch   900, train loss 1.040569, train error 36.70,  test loss 1.645137, test error 53.27
# Training model with  26 hidden variables
# Epoch     0, train loss 2.115736, train error 78.35,  test loss 2.050428, test error 77.75
# Epoch   100, train loss 1.171433, train error 38.10,  test loss 1.294036, test error 47.97
# Epoch   200, train loss 1.034414, train error 34.02,  test loss 1.440920, test error 49.12
# Epoch   300, train loss 0.954669, train error 30.90,  test loss 1.539135, test error 50.20
# Epoch   400, train loss 0.912235, train error 30.20,  test loss 1.653815, test error 51.82
# Epoch   500, train loss 0.892025, train error 29.35,  test loss 1.749812, test error 52.47
# Epoch   600, train loss 0.862905, train error 28.22,  test loss 1.828865, test error 53.37
# Epoch   700, train loss 0.862951, train error 28.90,  test loss 1.963266, test error 53.32
# Epoch   800, train loss 0.841004, train error 28.17,  test loss 1.982211, test error 53.02
# Epoch   900, train loss 0.841001, train error 28.88,  test loss 2.047128, test error 53.37
# Training model with  30 hidden variables
# Epoch     0, train loss 2.186210, train error 80.80,  test loss 2.148356, test error 79.80
# Epoch   100, train loss 1.181185, train error 39.15,  test loss 1.366492, test error 50.05
# Epoch   200, train loss 0.971511, train error 31.90,  test loss 1.515349, test error 50.75
# Epoch   300, train loss 0.882933, train error 30.00,  test loss 1.757398, test error 52.27
# Epoch   400, train loss 0.809050, train error 26.57,  test loss 1.962890, test error 52.77
# Epoch   500, train loss 0.780353, train error 25.88,  test loss 2.179576, test error 53.75
# Epoch   600, train loss 0.750876, train error 24.80,  test loss 2.302116, test error 54.22
# Epoch   700, train loss 0.724095, train error 24.35,  test loss 2.502676, test error 55.25
# Epoch   800, train loss 0.707146, train error 23.38,  test loss 2.654762, test error 55.30
# Epoch   900, train loss 0.699029, train error 23.77,  test loss 2.802953, test error 55.70
# Training model with  35 hidden variables
# Epoch     0, train loss 2.113798, train error 78.35,  test loss 2.065448, test error 77.28
# Epoch   100, train loss 1.047315, train error 34.35,  test loss 1.412071, test error 50.82
# Epoch   200, train loss 0.818575, train error 26.50,  test loss 1.693381, test error 52.20
# Epoch   300, train loss 0.710843, train error 23.97,  test loss 2.057861, test error 54.10
# Epoch   400, train loss 0.655542, train error 22.42,  test loss 2.430780, test error 55.70
# Epoch   500, train loss 0.600531, train error 20.70,  test loss 2.767156, test error 56.00
# Epoch   600, train loss 0.537077, train error 18.05,  test loss 3.028693, test error 56.40
# Epoch   700, train loss 0.509546, train error 17.50,  test loss 3.339022, test error 57.52
# Epoch   800, train loss 0.545544, train error 19.22,  test loss 3.597382, test error 58.20
# Epoch   900, train loss 0.485921, train error 16.60,  test loss 3.799197, test error 56.62
# Training model with  40 hidden variables
# Epoch     0, train loss 2.127964, train error 78.93,  test loss 2.083750, test error 78.10
# Epoch   100, train loss 0.964112, train error 31.90,  test loss 1.479250, test error 51.00
# Epoch   200, train loss 0.684293, train error 23.05,  test loss 1.996392, test error 53.77
# Epoch   300, train loss 0.551029, train error 18.50,  test loss 2.602575, test error 54.97
# Epoch   400, train loss 0.478367, train error 16.62,  test loss 3.288060, test error 55.12
# Epoch   500, train loss 0.360642, train error 12.20,  test loss 4.012337, test error 56.40
# Epoch   600, train loss 0.322655, train error 10.92,  test loss 4.635782, test error 57.20
# Epoch   700, train loss 0.387818, train error 12.95,  test loss 5.335463, test error 57.42
# Epoch   800, train loss 0.344658, train error 12.47,  test loss 5.800427, test error 58.75
# Epoch   900, train loss 0.239487, train error 8.32,  test loss 6.233307, test error 57.22
# Training model with  45 hidden variables
# Epoch     0, train loss 2.076900, train error 77.32,  test loss 2.006456, test error 75.57
# Epoch   100, train loss 0.817772, train error 26.07,  test loss 1.515265, test error 49.97
# Epoch   200, train loss 0.481492, train error 14.97,  test loss 2.279838, test error 53.87
# Epoch   300, train loss 0.343124, train error 11.47,  test loss 3.363905, test error 56.32
# Epoch   400, train loss 0.220326, train error 7.07,  test loss 4.583739, test error 56.65
# Epoch   500, train loss 0.146113, train error 4.67,  test loss 5.743219, test error 56.40
# Epoch   600, train loss 0.128859, train error 4.45,  test loss 6.912613, test error 57.00
# Epoch   700, train loss 0.013813, train error -0.00,  test loss 7.965572, test error 56.87
# Epoch   800, train loss 0.008431, train error -0.00,  test loss 8.666749, test error 57.17
# Epoch   900, train loss 0.006134, train error -0.00,  test loss 9.181439, test error 57.22
# Training model with  50 hidden variables
# Epoch     0, train loss 2.037109, train error 76.45,  test loss 1.947618, test error 74.78
# Epoch   100, train loss 0.724817, train error 23.32,  test loss 1.595425, test error 49.95
# Epoch   200, train loss 0.348016, train error 9.95,  test loss 2.730633, test error 55.00
# Epoch   300, train loss 0.151276, train error 3.37,  test loss 4.341858, test error 56.40
# Epoch   400, train loss 0.029621, train error 0.05,  test loss 6.073876, test error 57.00
# Epoch   500, train loss 0.013002, train error -0.00,  test loss 7.056958, test error 57.35
# Epoch   600, train loss 0.008093, train error -0.00,  test loss 7.719812, test error 57.27
# Epoch   700, train loss 0.005732, train error -0.00,  test loss 8.190256, test error 57.42
# Epoch   800, train loss 0.004418, train error -0.00,  test loss 8.579594, test error 57.42
# Epoch   900, train loss 0.003565, train error -0.00,  test loss 8.902440, test error 57.47
# Training model with  55 hidden variables
# Epoch     0, train loss 2.067141, train error 77.47,  test loss 2.007289, test error 76.78
# Epoch   100, train loss 0.664650, train error 20.62,  test loss 1.594685, test error 50.50
# Epoch   200, train loss 0.248241, train error 6.45,  test loss 2.902361, test error 52.30
# Epoch   300, train loss 0.049367, train error 0.10,  test loss 4.623705, test error 54.77
# Epoch   400, train loss 0.016034, train error -0.00,  test loss 5.741310, test error 54.37
# Epoch   500, train loss 0.009183, train error -0.00,  test loss 6.436931, test error 54.65
# Epoch   600, train loss 0.006234, train error -0.00,  test loss 6.903138, test error 54.77
# Epoch   700, train loss 0.004649, train error -0.00,  test loss 7.269921, test error 54.60
# Epoch   800, train loss 0.003670, train error -0.00,  test loss 7.568997, test error 54.55
# Epoch   900, train loss 0.003004, train error -0.00,  test loss 7.819682, test error 54.77
# Training model with  60 hidden variables
# Epoch     0, train loss 2.068890, train error 77.15,  test loss 2.006988, test error 76.90
# Epoch   100, train loss 0.536243, train error 15.90,  test loss 1.782736, test error 52.10
# Epoch   200, train loss 0.096623, train error 0.65,  test loss 3.572114, test error 54.92
# Epoch   300, train loss 0.018255, train error -0.00,  test loss 4.968001, test error 55.52
# Epoch   400, train loss 0.008986, train error -0.00,  test loss 5.669069, test error 55.87
# Epoch   500, train loss 0.005637, train error -0.00,  test loss 6.125247, test error 56.12
# Epoch   600, train loss 0.004104, train error -0.00,  test loss 6.466606, test error 56.22
# Epoch   700, train loss 0.003144, train error -0.00,  test loss 6.737769, test error 56.30
# Epoch   800, train loss 0.002537, train error -0.00,  test loss 6.967058, test error 56.35
# Epoch   900, train loss 0.002111, train error -0.00,  test loss 7.160599, test error 56.35
# Training model with  70 hidden variables
# Epoch     0, train loss 2.052979, train error 76.50,  test loss 1.993640, test error 76.60
# Epoch   100, train loss 0.366559, train error 9.02,  test loss 2.062217, test error 53.82
# Epoch   200, train loss 0.033135, train error -0.00,  test loss 3.872143, test error 55.52
# Epoch   300, train loss 0.011092, train error -0.00,  test loss 4.717029, test error 55.45
# Epoch   400, train loss 0.006176, train error -0.00,  test loss 5.183798, test error 55.45
# Epoch   500, train loss 0.004158, train error -0.00,  test loss 5.509650, test error 55.37
# Epoch   600, train loss 0.003094, train error -0.00,  test loss 5.757762, test error 55.42
# Epoch   700, train loss 0.002422, train error -0.00,  test loss 5.965644, test error 55.62
# Epoch   800, train loss 0.001982, train error -0.00,  test loss 6.134915, test error 55.60
# Epoch   900, train loss 0.001671, train error -0.00,  test loss 6.280475, test error 55.67
# Training model with  80 hidden variables
# Epoch     0, train loss 2.030819, train error 75.68,  test loss 1.974363, test error 75.65
# Epoch   100, train loss 0.237481, train error 4.82,  test loss 2.153792, test error 52.87
# Epoch   200, train loss 0.019537, train error -0.00,  test loss 3.509802, test error 53.90
# Epoch   300, train loss 0.007862, train error -0.00,  test loss 4.065742, test error 53.80
# Epoch   400, train loss 0.004664, train error -0.00,  test loss 4.405617, test error 53.70
# Epoch   500, train loss 0.003224, train error -0.00,  test loss 4.643003, test error 53.60
# Epoch   600, train loss 0.002428, train error -0.00,  test loss 4.826610, test error 53.60
# Epoch   700, train loss 0.001933, train error -0.00,  test loss 4.974301, test error 53.75
# Epoch   800, train loss 0.001592, train error -0.00,  test loss 5.104980, test error 53.70
# Epoch   900, train loss 0.001348, train error -0.00,  test loss 5.214190, test error 53.65
# Training model with  90 hidden variables
# Epoch     0, train loss 2.022272, train error 75.40,  test loss 1.933297, test error 74.93
# Epoch   100, train loss 0.163522, train error 1.17,  test loss 2.283844, test error 53.90
# Epoch   200, train loss 0.015888, train error -0.00,  test loss 3.535394, test error 54.47
# Epoch   300, train loss 0.006834, train error -0.00,  test loss 4.016518, test error 54.32
# Epoch   400, train loss 0.004140, train error -0.00,  test loss 4.323086, test error 54.50
# Epoch   500, train loss 0.002898, train error -0.00,  test loss 4.536473, test error 54.57
# Epoch   600, train loss 0.002200, train error -0.00,  test loss 4.704394, test error 54.55
# Epoch   700, train loss 0.001758, train error -0.00,  test loss 4.844176, test error 54.52
# Epoch   800, train loss 0.001454, train error -0.00,  test loss 4.960331, test error 54.45
# Epoch   900, train loss 0.001234, train error -0.00,  test loss 5.059988, test error 54.50
# Training model with 100 hidden variables
# Epoch     0, train loss 2.020290, train error 76.00,  test loss 1.955291, test error 75.65
# Epoch   100, train loss 0.092062, train error 0.07,  test loss 2.235560, test error 52.10
# Epoch   200, train loss 0.011934, train error -0.00,  test loss 3.043023, test error 51.32
# Epoch   300, train loss 0.005598, train error -0.00,  test loss 3.399044, test error 51.25
# Epoch   400, train loss 0.003486, train error -0.00,  test loss 3.618381, test error 51.50
# Epoch   500, train loss 0.002483, train error -0.00,  test loss 3.780484, test error 51.37
# Epoch   600, train loss 0.001901, train error -0.00,  test loss 3.906556, test error 51.40
# Epoch   700, train loss 0.001528, train error -0.00,  test loss 4.011281, test error 51.32
# Epoch   800, train loss 0.001270, train error -0.00,  test loss 4.099812, test error 51.30
# Epoch   900, train loss 0.001082, train error -0.00,  test loss 4.177006, test error 51.32
# Training model with 120 hidden variables
# Epoch     0, train loss 2.003334, train error 74.18,  test loss 1.897407, test error 73.88
# Epoch   100, train loss 0.049260, train error -0.00,  test loss 2.263734, test error 49.92
# Epoch   200, train loss 0.009311, train error -0.00,  test loss 2.867255, test error 49.25
# Epoch   300, train loss 0.004620, train error -0.00,  test loss 3.145469, test error 49.15
# Epoch   400, train loss 0.002970, train error -0.00,  test loss 3.328778, test error 49.20
# Epoch   500, train loss 0.002141, train error -0.00,  test loss 3.460900, test error 49.40
# Epoch   600, train loss 0.001656, train error -0.00,  test loss 3.566614, test error 49.60
# Epoch   700, train loss 0.001339, train error -0.00,  test loss 3.653829, test error 49.50
# Epoch   800, train loss 0.001119, train error -0.00,  test loss 3.728033, test error 49.50
# Epoch   900, train loss 0.000957, train error -0.00,  test loss 3.791905, test error 49.62
# Training model with 140 hidden variables
# Epoch     0, train loss 1.946448, train error 72.57,  test loss 1.864614, test error 71.97
# Epoch   100, train loss 0.034372, train error -0.00,  test loss 2.248192, test error 50.35
# Epoch   200, train loss 0.007884, train error -0.00,  test loss 2.759170, test error 50.25
# Epoch   300, train loss 0.004078, train error -0.00,  test loss 3.002605, test error 50.35
# Epoch   400, train loss 0.002655, train error -0.00,  test loss 3.162472, test error 50.22
# Epoch   500, train loss 0.001935, train error -0.00,  test loss 3.281049, test error 50.25
# Epoch   600, train loss 0.001507, train error -0.00,  test loss 3.375040, test error 50.25
# Epoch   700, train loss 0.001224, train error -0.00,  test loss 3.453105, test error 50.30
# Epoch   800, train loss 0.001025, train error -0.00,  test loss 3.520444, test error 50.37
# Epoch   900, train loss 0.000879, train error -0.00,  test loss 3.578543, test error 50.30
# Training model with 160 hidden variables
# Epoch     0, train loss 1.949072, train error 72.05,  test loss 1.852963, test error 73.47
# Epoch   100, train loss 0.028939, train error -0.00,  test loss 2.233161, test error 50.67
# Epoch   200, train loss 0.007210, train error -0.00,  test loss 2.672071, test error 50.65
# Epoch   300, train loss 0.003794, train error -0.00,  test loss 2.887796, test error 50.77
# Epoch   400, train loss 0.002494, train error -0.00,  test loss 3.033356, test error 50.90
# Epoch   500, train loss 0.001827, train error -0.00,  test loss 3.140588, test error 51.07
# Epoch   600, train loss 0.001427, train error -0.00,  test loss 3.225440, test error 50.92
# Epoch   700, train loss 0.001162, train error -0.00,  test loss 3.297318, test error 50.90
# Epoch   800, train loss 0.000975, train error -0.00,  test loss 3.358333, test error 50.92
# Epoch   900, train loss 0.000837, train error -0.00,  test loss 3.411123, test error 50.90
# Training model with 180 hidden variables
# Epoch     0, train loss 1.955110, train error 71.32,  test loss 1.877182, test error 71.85
# Epoch   100, train loss 0.024678, train error -0.00,  test loss 2.059622, test error 47.95
# Epoch   200, train loss 0.006584, train error -0.00,  test loss 2.422210, test error 48.30
# Epoch   300, train loss 0.003521, train error -0.00,  test loss 2.601758, test error 48.45
# Epoch   400, train loss 0.002329, train error -0.00,  test loss 2.724057, test error 48.50
# Epoch   500, train loss 0.001714, train error -0.00,  test loss 2.814641, test error 48.52
# Epoch   600, train loss 0.001343, train error -0.00,  test loss 2.887889, test error 48.62
# Epoch   700, train loss 0.001096, train error -0.00,  test loss 2.948621, test error 48.60
# Epoch   800, train loss 0.000922, train error -0.00,  test loss 3.000962, test error 48.52
# Epoch   900, train loss 0.000793, train error -0.00,  test loss 3.047147, test error 48.57
# Training model with 200 hidden variables
# Epoch     0, train loss 1.933387, train error 70.65,  test loss 1.858209, test error 71.20
# Epoch   100, train loss 0.021645, train error -0.00,  test loss 2.031267, test error 48.45
# Epoch   200, train loss 0.006183, train error -0.00,  test loss 2.346095, test error 48.15
# Epoch   300, train loss 0.003355, train error -0.00,  test loss 2.509581, test error 48.30
# Epoch   400, train loss 0.002238, train error -0.00,  test loss 2.620103, test error 48.47
# Epoch   500, train loss 0.001651, train error -0.00,  test loss 2.702214, test error 48.55
# Epoch   600, train loss 0.001296, train error -0.00,  test loss 2.768572, test error 48.45
# Epoch   700, train loss 0.001060, train error -0.00,  test loss 2.824200, test error 48.42
# Epoch   800, train loss 0.000892, train error -0.00,  test loss 2.872100, test error 48.42
# Epoch   900, train loss 0.000768, train error -0.00,  test loss 2.913547, test error 48.37
# Training model with 250 hidden variables
# Epoch     0, train loss 1.885657, train error 67.77,  test loss 1.805493, test error 69.77
# Epoch   100, train loss 0.017067, train error -0.00,  test loss 1.962010, test error 48.02
# Epoch   200, train loss 0.005398, train error -0.00,  test loss 2.222747, test error 47.85
# Epoch   300, train loss 0.003014, train error -0.00,  test loss 2.364627, test error 47.75
# Epoch   400, train loss 0.002037, train error -0.00,  test loss 2.458641, test error 47.75
# Epoch   500, train loss 0.001515, train error -0.00,  test loss 2.531425, test error 47.92
# Epoch   600, train loss 0.001196, train error -0.00,  test loss 2.589782, test error 47.87
# Epoch   700, train loss 0.000982, train error -0.00,  test loss 2.637764, test error 47.92
# Epoch   800, train loss 0.000830, train error -0.00,  test loss 2.679847, test error 48.02
# Epoch   900, train loss 0.000716, train error -0.00,  test loss 2.716832, test error 48.02
# Training model with 300 hidden variables
# Epoch     0, train loss 1.870595, train error 67.02,  test loss 1.787224, test error 68.32
# Epoch   100, train loss 0.014792, train error -0.00,  test loss 1.956277, test error 47.67
# Epoch   200, train loss 0.004857, train error -0.00,  test loss 2.192907, test error 47.12
# Epoch   300, train loss 0.002748, train error -0.00,  test loss 2.321197, test error 47.12
# Epoch   400, train loss 0.001870, train error -0.00,  test loss 2.409806, test error 47.27
# Epoch   500, train loss 0.001398, train error -0.00,  test loss 2.476564, test error 47.32
# Epoch   600, train loss 0.001107, train error -0.00,  test loss 2.531138, test error 47.40
# Epoch   700, train loss 0.000911, train error -0.00,  test loss 2.576692, test error 47.42
# Epoch   800, train loss 0.000771, train error -0.00,  test loss 2.616042, test error 47.45
# Epoch   900, train loss 0.000666, train error -0.00,  test loss 2.650472, test error 47.50
# Training model with 400 hidden variables
# Epoch     0, train loss 1.862366, train error 67.07,  test loss 1.776754, test error 68.62
# Epoch   100, train loss 0.011698, train error -0.00,  test loss 1.772027, test error 46.32
# Epoch   200, train loss 0.004184, train error -0.00,  test loss 1.950427, test error 46.67
# Epoch   300, train loss 0.002425, train error -0.00,  test loss 2.049486, test error 46.52
# Epoch   400, train loss 0.001670, train error -0.00,  test loss 2.118839, test error 46.55
# Epoch   500, train loss 0.001259, train error -0.00,  test loss 2.171793, test error 46.60
# Epoch   600, train loss 0.001002, train error -0.00,  test loss 2.214585, test error 46.62
# Epoch   700, train loss 0.000828, train error -0.00,  test loss 2.250874, test error 46.60
# Epoch   800, train loss 0.000703, train error -0.00,  test loss 2.281801, test error 46.52
# Epoch   900, train loss 0.000609, train error -0.00,  test loss 2.309642, test error 46.57

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
